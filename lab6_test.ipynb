# %%
from lab6.komiwojazer import * 
from lab6.page_rank import *

# %% [markdown]
# # Zadanie 1

# %%
# G = nx.DiGraph()
# G.add_edges_from([('A', 'B'), ('A', 'C'), ('A', 'D'), ('B', 'A'), ('B', 'D'), ('C', 'B'), ('D', 'C')])

G = generate_random_suitable_digraph(5)

print('METODA A')
pagerank_values = pagerank_a(G)
print_pagerank(G, pagerank_values)

print('METODA B')
pagerank_values = pagerank_b(G)
print_pagerank(G, pagerank_values)

nx.draw_circular(G, with_labels=True)
# Out:
# METODA A
# 0: 0.1710004610419548
# 1: 0.16864914707238354
# 2: 0.24467496542185332
# 3: 0.1710004610419548
# 4: 0.24467496542185332
# METODA B
# 0: 0.14706125440020712
# 1: 0.15500206624017604
# 2: 0.2754377124797049
# 3: 0.14706125440020712
# 4: 0.2754377124797049

# %% [markdown]
# # Zadanie 2

# %%
# Dane punktów
points = [
    (29, -82),
    (-11, -86),
    (35, 36),
    (96, -15),
    (-3, -71),
    (-49, 97),
    (44, 13),
    (6, -22),
    (38, -82),
    (34, 18),
    (-7, 57),
    (-5, -54),
    (-49, 13),
    (60, 94),
    (-44, -16),
    (-66, -29),
    (93, 35),
    (-32, 41),
    (67, -15),
    (37, -9),
    (49, -3),
    (79, 49),
    (-37, 26),
    (60, -75),
    (-28, 41),
    (0, -22),
    (-51, -9),
    (-68, -97),
    (-40, 3),
    (-15, 28),
    (61, 15),
    (70, -47),
    (-70, -40),
    (-70, 72),
    (51, 1),
    (-25, 56),
    (-52, 23),
    (15, -69),
    (33, 51),
    (40, -30),
    (84, 80),
    (-4, 26),
    (-22, -82),
    (-47, -54),
    (3, -25),
    (-21, 29),
    (-3, -70),
    (-87, -73),
    (-85, 69),
    (-9, 65),
    (-36, -79),
    (44, -29),
    (-63, -74),
    (-46, -4),
    (-51, 22),
    (100, -38),
    (87, -50),
    (-97, -43),
    (-56, 32),
    (-72, 95),
    (89, 37),
    (38, -52),
    (73, -16),
    (51, -51),
    (-47, -17),
    (74, 47),
    (-85, 81),
    (-9, 4),
    (-25, -59),
    (-72, 53),
    (88, 85),
    (-60, 24),
    (86, 71),
    (35, 85),
    (58, -83),
    (75, -70),
    (-84, -41),
    (58, 36),
    (42, -66),
    (35, -55),
    (-72, 51),
    (-28, 76),
    (14, -37),
    (-42, -60),
    (-97, 50),
    (-99, 93),
    (42, 83),
    (-11, 74),
    (12, 43),
    (84, 71),
    (98, -36),
    (-30, 22),
    (51, -2),
    (75, -16),
    (40, -99),
    (86, -78),
    (82, -23),
    (55, 27),
    (97, 25),
    (-72, 24),
    (82, 17),
    (64, 74),
    (9, 81),
    (-62, -68),
    (38, -80),
    (-7, -97),
    (-89, 62),
    (-61, -89),
    (-78, -29),
    (69, -64),
    (57, 38),
    (89, -53),
    (-33, 44),
    (-15, 88),
    (19, -21),
    (68, 19),
    (68, 93),
    (96, -11),
    (13, 98),
    (-63, 22),
    (-6, -83),
    (-20, 89),
    (-62, 74),
    (-97, 81),
    (57, 14),
    (92, 94),
    (-70, -94),
    (41, -49),
    (-59, 4),
    (30, 28),
    (-46, -49),
    (-65, -89),
    (-16, -40),
    (-73, -53),
    (-86, -26),
    (-37, -2),
    (25, 63),
    (-17, -19),
    (2, -9),
    (56, 73),
    (74, 7),
    (14, 2),
    (-25, -28),
    (38, -85),
    (34, 61),
    (29, -73),
    (47, -92),
    (29, -14),
    (26, -87),
    (18, -10)
]

# %%
# Uruchomienie algorytmu symulowanego wyżarzania
best_path, best_distance, first_path = simulated_annealing(points)

# Wyświetlenie wyników
print("Pierwsza ścieżka:", first_path)
print("Najkrótsza ścieżka:", best_path)
print("Długość ścieżki:", best_distance)

# Wyrysowanie najkrótszej ścieżki na wykresie
plot_path(points, best_path)
# Out:
# d:\Git\graph_theory_labs\lab6\komiwojazer.py:32: RuntimeWarning: overflow encountered in scalar divide
#   acceptance_probability = np.exp((distance_current - distance_new) / temperature)
# Pierwsza ścieżka: 14337.823372008901
# Najkrótsza ścieżka: [141, 9, 129, 2, 97, 77, 110, 101, 139, 144, 38, 88, 136, 102, 87, 49, 10, 35, 112, 17, 24, 41, 29, 45, 91, 22, 12, 28, 135, 142, 132, 68, 46, 4, 120, 105, 1, 42, 50, 107, 131, 27, 126, 47, 52, 103, 83, 43, 130, 133, 32, 76, 57, 134, 108, 15, 64, 14, 26, 53, 128, 54, 36, 58, 71, 119, 99, 80, 69, 84, 106, 48, 66, 123, 85, 59, 33, 122, 5, 81, 121, 113, 118, 73, 86, 13, 116, 125, 70, 40, 72, 89, 21, 65, 60, 16, 98, 100, 140, 115, 30, 124, 6, 34, 20, 92, 117, 3, 55, 90, 96, 93, 62, 18, 19, 147, 39, 51, 63, 127, 61, 79, 78, 109, 31, 56, 111, 95, 75, 23, 74, 146, 94, 143, 8, 104, 148, 0, 145, 37, 11, 82, 7, 44, 25, 137, 67, 138, 114, 149]
# Długość ścieżki: 2085.9636625149033
